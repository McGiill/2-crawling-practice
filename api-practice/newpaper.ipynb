# %% [markdown]
# # 신문기사 데이터 추출 및 CSV 저장
# 이 노트북에서는 GDELT API를 사용하여 특정 키워드에 맞는 신문기사를 추출하고, Newspaper3k 라이브러리를 사용해 각 기사의 본문을 파싱한 후, 이를 CSV 파일로 저장하는 방법을 설명합니다.

# %% [markdown]
# ### 1. 필요한 라이브러리 설치 및 임포트
#
# 이 단계에서는 필요한 라이브러리들을 설치합니다. gdeltdoc는 GDELT API를 사용하여 기사를 검색할 때 필요하고, newspaper3k는 각 기사에서 본문을 추출할 때 사용됩니다. 또한, pandas 라이브러리를 사용해 데이터를 쉽게 다룰 수 있습니다.

# %%
# !pip install gdeltdoc
# !pip install newspaper3k
# !pip install lxml[html_clean]
# !pip install pandas
# Out:
# Collecting gdeltdoc
#   Downloading gdeltdoc-1.10.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: pandas>=2.2.3 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from gdeltdoc) (2.2.3)
# Requirement already satisfied: requests>=2.32.3 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from gdeltdoc) (2.32.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from pandas>=2.2.3->gdeltdoc) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from pandas>=2.2.3->gdeltdoc) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from pandas>=2.2.3->gdeltdoc) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from pandas>=2.2.3->gdeltdoc) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from requests>=2.32.3->gdeltdoc) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from requests>=2.32.3->gdeltdoc) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from requests>=2.32.3->gdeltdoc) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from requests>=2.32.3->gdeltdoc) (2025.1.31)
# Requirement already satisfied: six>=1.5 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.2.3->gdeltdoc) (1.17.0)
# Downloading gdeltdoc-1.10.1-py3-none-any.whl (15 kB)
# Installing collected packages: gdeltdoc
# Successfully installed gdeltdoc-1.10.1
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting newspaper3k
#   Downloading newspaper3k-0.2.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from newspaper3k) (4.13.3)
# Collecting Pillow>=3.3.0 (from newspaper3k)
#   Downloading pillow-11.1.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: PyYAML>=3.11 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from newspaper3k) (6.0.2)
# Collecting cssselect>=0.9.2 (from newspaper3k)
#   Downloading cssselect-1.3.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting lxml>=3.6.0 (from newspaper3k)
#   Downloading lxml-5.3.1-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Collecting nltk>=3.2.1 (from newspaper3k)
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: requests>=2.10.0 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from newspaper3k) (2.32.3)
# Collecting feedparser>=5.2.1 (from newspaper3k)
#   Downloading feedparser-6.0.11-py3-none-any.whl.metadata (2.4 kB)
# Collecting tldextract>=2.0.1 (from newspaper3k)
#   Downloading tldextract-5.1.3-py3-none-any.whl.metadata (11 kB)
# Collecting feedfinder2>=0.0.4 (from newspaper3k)
#   Downloading feedfinder2-0.0.4.tar.gz (3.3 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting jieba3k>=0.35.1 (from newspaper3k)
#   Downloading jieba3k-0.35.1.zip (7.4 MB)
#      ---------------------------------------- 0.0/7.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/7.4 MB ? eta -:--:--
#      -- ------------------------------------- 0.5/7.4 MB 2.1 MB/s eta 0:00:04
#      -------- ------------------------------- 1.6/7.4 MB 3.5 MB/s eta 0:00:02
#      ------------------ --------------------- 3.4/7.4 MB 5.3 MB/s eta 0:00:01
#      ------------------------ --------------- 4.5/7.4 MB 5.1 MB/s eta 0:00:01
#      ----------------------------- ---------- 5.5/7.4 MB 5.2 MB/s eta 0:00:01
#      ----------------------------------- ---- 6.6/7.4 MB 5.2 MB/s eta 0:00:01
#      ---------------------------------------  7.3/7.4 MB 5.0 MB/s eta 0:00:01
#      ---------------------------------------- 7.4/7.4 MB 4.5 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from newspaper3k) (2.9.0.post0)
# Collecting tinysegmenter==0.3 (from newspaper3k)
#   Downloading tinysegmenter-0.3.tar.gz (16 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (4.12.2)
# Requirement already satisfied: six in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from feedfinder2>=0.0.4->newspaper3k) (1.17.0)
# Collecting sgmllib3k (from feedparser>=5.2.1->newspaper3k)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting click (from nltk>=3.2.1->newspaper3k)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting joblib (from nltk>=3.2.1->newspaper3k)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting regex>=2021.8.3 (from nltk>=3.2.1->newspaper3k)
#   Downloading regex-2024.11.6-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk>=3.2.1->newspaper3k)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from requests>=2.10.0->newspaper3k) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from requests>=2.10.0->newspaper3k) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from requests>=2.10.0->newspaper3k) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from requests>=2.10.0->newspaper3k) (2025.1.31)
# Collecting requests-file>=1.4 (from tldextract>=2.0.1->newspaper3k)
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting filelock>=3.0.8 (from tldextract>=2.0.1->newspaper3k)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: colorama in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from click->nltk>=3.2.1->newspaper3k) (0.4.6)
# Downloading newspaper3k-0.2.8-py3-none-any.whl (211 kB)
# Downloading cssselect-1.3.0-py3-none-any.whl (18 kB)
# Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
# Downloading lxml-5.3.1-cp312-cp312-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ------------------- -------------------- 1.8/3.8 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 8.7 MB/s eta 0:00:00
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------- ----- 1.3/1.5 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 6.6 MB/s eta 0:00:00
# Downloading pillow-11.1.0-cp312-cp312-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    --------------------------- ------------ 1.8/2.6 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 8.4 MB/s eta 0:00:00
# Downloading tldextract-5.1.3-py3-none-any.whl (104 kB)
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading regex-2024.11.6-cp312-cp312-win_amd64.whl (273 kB)
# Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Building wheels for collected packages: tinysegmenter, feedfinder2, jieba3k, sgmllib3k
#   Building wheel for tinysegmenter (pyproject.toml): started
#   Building wheel for tinysegmenter (pyproject.toml): finished with status 'done'
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13668 sha256=6439aa6eb86b30b225aa23d4715755b678840e3fde9cad87083334262719a0b6
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\a5\91\9f\00d66475960891a64867914273fcaf78df6cb04d905b104a2a
#   Building wheel for feedfinder2 (pyproject.toml): started
#   Building wheel for feedfinder2 (pyproject.toml): finished with status 'done'
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3411 sha256=459e1ea82853dedf8b78c3390230ccdd5c8e482832352ffd55a4e29a82a148df
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\9f\9f\fb\364871d7426d3cdd4d293dcf7e53d97f160c508b2ccf00cc79
#   Building wheel for jieba3k (pyproject.toml): started
#   Building wheel for jieba3k (pyproject.toml): finished with status 'done'
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398411 sha256=405830122ee66b284d31ffe638d555a635a23b8b0b266e931ad5ea37926f6208
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\26\72\f7\fff392a8d4ea988dea4ccf9788599d09462a7f5e51e04f8a92
#   Building wheel for sgmllib3k (pyproject.toml): started
#   Building wheel for sgmllib3k (pyproject.toml): finished with status 'done'
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6105 sha256=2e67a2ec027dd4a863ba2f8adc88aa138d73043d94141edc0c4666169edfc78c
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\03\f5\1a\23761066dac1d0e8e683e5fdb27e12de53209d05a4a37e6246
# Successfully built tinysegmenter feedfinder2 jieba3k sgmllib3k
# Installing collected packages: tinysegmenter, sgmllib3k, jieba3k, tqdm, regex, Pillow, lxml, joblib, filelock, feedparser, cssselect, click, requests-file, nltk, feedfinder2, tldextract, newspaper3k
# Successfully installed Pillow-11.1.0 click-8.1.8 cssselect-1.3.0 feedfinder2-0.0.4 feedparser-6.0.11 filelock-3.18.0 jieba3k-0.35.1 joblib-1.4.2 lxml-5.3.1 newspaper3k-0.2.8 nltk-3.9.1 regex-2024.11.6 requests-file-2.1.0 sgmllib3k-1.0.0 tinysegmenter-0.3 tldextract-5.1.3 tqdm-4.67.1
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: lxml[html_clean] in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (5.3.1)
# Collecting lxml_html_clean (from lxml[html_clean])
#   Downloading lxml_html_clean-0.4.1-py3-none-any.whl.metadata (2.4 kB)
# Downloading lxml_html_clean-0.4.1-py3-none-any.whl (14 kB)
# Installing collected packages: lxml_html_clean
# Successfully installed lxml_html_clean-0.4.1
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\desktop\hateslop\2-crawling-practice\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### 2. 라이브러리 임포트
# 필요한 라이브러리를 코드에 임포트합니다.

# %%
from gdeltdoc import GdeltDoc, Filters
from newspaper import Article
import pandas as pd

# %% [markdown]
# ### 3. GDELT API 필터 설정
#
# GDELT API를 사용하여 원하는 기사를 추출하기 위한 필터를 설정합니다. Filters 클래스를 사용하여 날짜, 키워드, 도메인 등 다양한 조건을 지정할 수 있습니다.

# %%
f = Filters(
    keyword = "Microsoft",  # 키워드: Microsoft 관련 기사만 추출
    start_date = "2024-05-01",  # 시작 날짜
    end_date = "2024-05-25",  # 종료 날짜
    num_records=10,  # 가져올 기사의 수
    domain ="nytimes.com",  # 특정 도메인(여기서는 NYTimes)
    country="US",  # 국가 설정 (US)
)

# %% [markdown]
# ### 4. GDELT 데이터 검색
#
# 설정한 필터에 맞는 기사를 GDELT API를 통해 검색하여 결과를 pandas DataFrame으로 변환합니다.

# %%
# GDELT 객체 생성
gd = GdeltDoc()

# 필터에 맞는 기사 검색
articles = gd.article_search(f)

# 기사의 URL과 제목을 포함한 DataFrame 생성
articles_data = []
for index, row in articles.iterrows():
    url = row['url']
    title = row['title']
    
    # Newspaper3k 라이브러리를 사용하여 기사 본문 추출
    article = Article(url)
    article.download()
    article.parse()
    text = article.text  # 기사 본문
    
    # DataFrame에 추가
    articles_data.append({
        "title": title,
        "url": url,
        "text": text
    })

# DataFrame 생성
articles_df = pd.DataFrame(articles_data)

# 결과 출력
articles_df.head()  # 첫 5개의 기사 출력
# Out:
#                                                title  \
# 0  The C . E . O . s Who Just Wont Quit - The New...
# 1  C . Gordon Bell , Creator of a Personal Comput...
# 2  Wayve , an A . I . Start - Up for Autonomous D...
# 3  Biden to Announce A . I . Center in Wisconsin ...
# 4  How Rich Candidates Burned Cash on Running for...
#
#                                                  url  \
# 0  https://www.nytimes.com/2024/05/09/magazine/fo...
# 1  https://www.nytimes.com/2024/05/21/technology/...
# 2  https://www.nytimes.com/2024/05/06/technology/...
# 3  https://www.nytimes.com/2024/05/08/us/politics...
# 4  https://www.nytimes.com/2024/05/16/us/politics...
#
#                                                 text
# 0  Of the many riddles that confront corporate ch...
# 1  C. Gordon Bell, a technology visionary whose c...
# 2  Wayve, a London maker of artificial intelligen...
# 3  In a statement issued Wednesday, Foxconn defen...
# 4  The costly realm of campaign politics has clai...

# %% [markdown]
# ### 5. CSV 파일로 저장
#
# 최종적으로 추출한 기사 데이터를 pandas DataFrame으로 저장한 후, 이를 CSV 파일로 저장합니다.

# %%
# CSV 파일로 저장
articles_df.to_csv('articles_data.csv', index=False)
